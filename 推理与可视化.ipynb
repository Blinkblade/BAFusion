# %%
import torch
from torch import nn

# %%
model_path = "./work_dirs/bafpp-SGD-cspfpn-conv33-bn12-nope-aug/epoch_10.pth"

# %%
model = torch.load(model_path)

# %%
print(model.keys())
# 模型的超参数设置
print(model['meta'].keys())
# 信息和记录
print(model['message_hub'].keys())
# 优化器参数
print(model["optimizer"].keys())
# 模型权重
print(model["state_dict"].keys())
# Out:
# dict_keys(['meta', 'state_dict', 'message_hub', 'optimizer'])
# dict_keys(['epoch', 'iter', 'cfg', 'seed', 'experiment_name', 'time', 'mmengine_version', 'dataset_meta'])
# dict_keys(['log_scalars', 'runtime_info', 'resumed_keys'])
# dict_keys(['state', 'param_groups'])
# ...
